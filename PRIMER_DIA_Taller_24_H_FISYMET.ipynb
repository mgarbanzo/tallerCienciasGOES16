# %% [markdown]
# <a href="https://colab.research.google.com/github/mgarbanzo/tallerCienciasGOES16/blob/master/PRIMER_DIA_Taller_24_H_FISYMET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Control+m+m
#
# Control+m+y

# %% [markdown]
# # Esta es la primera vez en Colab.Research

# %%
print("HOLA")
# Out:
# HOLA

# %% [markdown]
# # ¿Que hay detras de Colab?

# %%
# !uname -a
# Out:
# Linux be350da0daf0 4.19.112+ #1 SMP Thu Jul 23 08:00:38 PDT 2020 x86_64 x86_64 x86_64 GNU/Linux

# %%
# !echo $PATH
# Out:
# /usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin

# %%
# !ls /
# Out:
# bin	 datalab  home	 lib64	opt   run   swift	       tmp    var
# boot	 dev	  lib	 media	proc  sbin  sys		       tools
# content  etc	  lib32  mnt	root  srv   tensorflow-1.15.2  usr

# %%
# !for x in {00..10}; do echo $x; done
# Out:
# 00
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10

# %% [markdown]
# https://tldp.org/LDP/abs/html/

# %% [markdown]
# # Esto es para Python
#
# Markdown

# %%
import numpy as np
import pylab as plt

# %%
A = np.random.randint(0,10,(10,10))

# %%
plt.figure()
plt.imshow(A)

# %% [markdown]
# # [github.com/mgarbanzo/tallerCienciasGOES16](github.com/mgarbanzo/tallerCienciasGOES16)

# %% [markdown]
# # METEO

# %%
# !wget https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2020/321/18/OR_ABI-L2-CMIPF-M6C05_G16_s20203211800151_e20203211809459_c20203211809549.nc
# Out:
# --2020-12-15 18:27:52--  https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2020/321/18/OR_ABI-L2-CMIPF-M6C05_G16_s20203211800151_e20203211809459_c20203211809549.nc
# Resolving noaa-goes16.s3.amazonaws.com (noaa-goes16.s3.amazonaws.com)... 52.216.249.116
# Connecting to noaa-goes16.s3.amazonaws.com (noaa-goes16.s3.amazonaws.com)|52.216.249.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96493489 (92M) [binary/octet-stream]
# Saving to: ‘OR_ABI-L2-CMIPF-M6C05_G16_s20203211800151_e20203211809459_c20203211809549.nc’
#
# OR_ABI-L2-CMIPF-M6C 100%[===================>]  92.02M  30.6MB/s    in 3.0s
#
# 2020-12-15 18:27:56 (30.6 MB/s) - ‘OR_ABI-L2-CMIPF-M6C05_G16_s20203211800151_e20203211809459_c20203211809549.nc’ saved [96493489/96493489]

# %%
# !pip install netCDF4
# Out:
# ...
#      |████████████████████████████████| 4.3MB 8.3MB/s
# ...
#      |████████████████████████████████| 296kB 42.6MB/s
# ...

# %%
import pylab as plt
import numpy as np
from netCDF4 import Dataset

# %%
ncABIC05t1 = Dataset("/content/OR_ABI-L2-CMIPF-M6C05_G16_s20203211800151_e20203211809459_c20203211809549.nc")

# %%
ncABIC05t1
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     naming_authority: gov.nesdis.noaa
#     Conventions: CF-1.7
#     Metadata_Conventions: Unidata Dataset Discovery v1.0
#     standard_name_vocabulary: CF Standard Name Table (v35, 20 July 2016)
#     institution: DOC/NOAA/NESDIS > U.S. Department of Commerce, National Oceanic and Atmospheric Administration, National Environmental Satellite, Data, and Information Services
#     project: GOES
#     production_site: NSOF
#     production_environment: OE
#     spatial_resolution: 1km at nadir
#     orbital_slot: GOES-East
#     platform_ID: G16
#     instrument_type: GOES R Series Advanced Baseline Imager
#     scene_id: Full Disk
#     instrument_ID: FM1
#     dataset_name: OR_ABI-L2-CMIPF-M6C05_G16_s20203211800151_e20203211809459_c20203211809549.nc
#     iso_series_metadata_id: 8c9e8150-3692-11e3-aa6e-0800200c9a66
#     title: ABI L2 Cloud and Moisture Imagery
# ...

# %%
datos1 = ncABIC05t1.variables['CMI'][:,:]

# %%
fig, ax = plt.subplots(1,figsize=(15,15))
plt.imshow(datos1,cmap='gray')
plt.colorbar()

# %%
fig, ax = plt.subplots(1,figsize=(15,15))
plt.imshow(datos1[3000:5000,3700:5700],cmap='gray')
plt.colorbar()

# %% [markdown]
# https://home.chpc.utah.edu/~u0553130/Brian_Blaylock/cgi-bin/goes16_download.cgi

# %% [markdown]
# # Series de tiempo

# %%
T1 = 5

# %%
dt = 0.01

# %%
st1 = np.arange(0,100,dt)

# %%
A1 = np.sin((2*np.pi*st1)/T1)

# %%
plt.figure(figsize=(15,5))
plt.plot(st1,A1)
